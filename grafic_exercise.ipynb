# %% [markdown]
# <a href="https://colab.research.google.com/github/raquelpaiva/DataGirls/blob/main/grafic_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criando um DataFrame de exemplo
dados = {
    'Ano': [2018, 2019, 2020, 2021, 2022],
    'Vendas': [150, 200, 250, 300, 400]
}
df = pd.DataFrame(dados)

# Plotando o gráfico de linhas
df.plot(x='Ano', y='Vendas', kind='line', marker='o', title='Vendas Anuais')
plt.xlabel('Ano')
plt.ylabel('Vendas')
plt.grid(True)
plt.show()
